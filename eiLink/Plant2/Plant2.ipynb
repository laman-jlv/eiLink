# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from google.colab import drive
drive.mount('/content/drive', timeout_ms=1200000)
from google.colab import data_table
def show(df):return data_table.DataTable(df)
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Plant 2

# %% [markdown]
# ##Generalities

# %%
generation2 = pd.read_csv("/content/drive/MyDrive/eiLink/Plant2/Plant_2_Generation_Data.csv")
weather2 = pd.read_csv("/content/drive/MyDrive/eiLink/Plant2/Plant_2_Weather_Sensor_Data.csv")

# %%
print(generation2.head(2))
print(weather2.head(2))
# Out:
#              DATE_TIME  PLANT_ID  ... DAILY_YIELD   TOTAL_YIELD
# 0  2020-05-15 00:00:00   4136001  ...      9425.0  2.429011e+06
# 1  2020-05-15 00:00:00   4136001  ...         0.0  1.215279e+09
#
# [2 rows x 7 columns]
#              DATE_TIME  PLANT_ID  ... MODULE_TEMPERATURE  IRRADIATION
# 0  2020-05-15 00:00:00   4136001  ...          25.060789          0.0
# 1  2020-05-15 00:15:00   4136001  ...          24.421869          0.0
#
# [2 rows x 6 columns]

# %% [markdown]
# Removing Seconds

# %%
generation2['DATE_TIME'] =  pd.to_datetime(generation2['DATE_TIME'], format='%Y-%m-%d %H:%M')
# .dt.strftime("%d-%m-%Y %H:%M")
weather2['DATE_TIME'] =  pd.to_datetime(weather2['DATE_TIME'], format='%Y-%m-%d %H:%M')
# .dt.strftime("%d-%m-%Y %H:%M")

# %%
show(generation2.head(10))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DATE_TIME</th>
#       <th>PLANT_ID</th>
#       <th>SOURCE_KEY</th>
#       <th>DC_POWER</th>
#       <th>AC_POWER</th>
#       <th>DAILY_YIELD</th>
#       <th>TOTAL_YIELD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>4UPUqMRk7TRMgml</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>9425.000000</td>
#       <td>2.429011e+06</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>81aHJ1q11NBPMrL</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>1.215279e+09</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>9kRcWv60rDACzjR</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3075.333333</td>
#       <td>2.247720e+09</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>Et9kgGMDl729KT4</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>269.933333</td>
#       <td>1.704250e+06</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>IQ2d7wF4YD8zU1Q</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3177.000000</td>
#       <td>1.994153e+07</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>LYwnQax7tkwH5Cb</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1872.500000</td>
#       <td>1.794959e+09</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>LlT2YUhhzqhg5Sw</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1094.357143</td>
#       <td>2.825928e+08</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>Mx2yZCDsyf6DPfv</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>5692.200000</td>
#       <td>2.453646e+06</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>NgDl19wMapZy17u</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1866.200000</td>
#       <td>1.115126e+08</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>PeE6FRyGXUgsRhN</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>651.200000</td>
#       <td>1.348351e+09</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
show(weather2.head(10))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DATE_TIME</th>
#       <th>PLANT_ID</th>
#       <th>SOURCE_KEY</th>
#       <th>AMBIENT_TEMPERATURE</th>
#       <th>MODULE_TEMPERATURE</th>
#       <th>IRRADIATION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-05-15 00:00:00</td>
#       <td>4136001</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020-05-15 00:15:00</td>
#       <td>4136001</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>26.880811</td>
#       <td>24.421869</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020-05-15 00:30:00</td>
#       <td>4136001</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>26.682055</td>
#       <td>24.427290</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020-05-15 00:45:00</td>
#       <td>4136001</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>26.500589</td>
#       <td>24.420678</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020-05-15 01:00:00</td>
#       <td>4136001</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>26.596148</td>
#       <td>25.088210</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2020-05-15 01:15:00</td>
#       <td>4136001</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>26.512740</td>
#       <td>25.317970</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2020-05-15 01:30:00</td>
#       <td>4136001</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>26.494339</td>
#       <td>25.217193</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2020-05-15 01:45:00</td>
#       <td>4136001</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>26.420410</td>
#       <td>25.065062</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2020-05-15 02:00:00</td>
#       <td>4136001</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>26.401946</td>
#       <td>24.691469</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2020-05-15 02:15:00</td>
#       <td>4136001</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>26.226078</td>
#       <td>24.559481</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Creatng one General Table

# %%
full_table2 = pd.merge(left=generation2, right=weather2, how="inner", left_on=['DATE_TIME', 'PLANT_ID'], right_on=['DATE_TIME', 'PLANT_ID'])
show(full_table2.head(10))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DATE_TIME</th>
#       <th>PLANT_ID</th>
#       <th>SOURCE_KEY_x</th>
#       <th>DC_POWER</th>
#       <th>AC_POWER</th>
#       <th>DAILY_YIELD</th>
#       <th>TOTAL_YIELD</th>
#       <th>SOURCE_KEY_y</th>
#       <th>AMBIENT_TEMPERATURE</th>
#       <th>MODULE_TEMPERATURE</th>
#       <th>IRRADIATION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>4UPUqMRk7TRMgml</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>9425.000000</td>
#       <td>2.429011e+06</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>81aHJ1q11NBPMrL</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>1.215279e+09</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>9kRcWv60rDACzjR</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3075.333333</td>
#       <td>2.247720e+09</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>Et9kgGMDl729KT4</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>269.933333</td>
#       <td>1.704250e+06</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>IQ2d7wF4YD8zU1Q</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3177.000000</td>
#       <td>1.994153e+07</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>LYwnQax7tkwH5Cb</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1872.500000</td>
#       <td>1.794959e+09</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>LlT2YUhhzqhg5Sw</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1094.357143</td>
#       <td>2.825928e+08</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>Mx2yZCDsyf6DPfv</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>5692.200000</td>
#       <td>2.453646e+06</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>NgDl19wMapZy17u</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1866.200000</td>
#       <td>1.115126e+08</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>PeE6FRyGXUgsRhN</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>651.200000</td>
#       <td>1.348351e+09</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print(full_table2.columns)
# Out:
# Index(['DATE_TIME', 'PLANT_ID', 'SOURCE_KEY_x', 'DC_POWER', 'AC_POWER',
#        'DAILY_YIELD', 'TOTAL_YIELD', 'SOURCE_KEY_y', 'AMBIENT_TEMPERATURE',
#        'MODULE_TEMPERATURE', 'IRRADIATION'],
#       dtype='object')

# %% [markdown]
# Naming and Counting Panels

# %%
test = full_table2.copy()

panels = test['SOURCE_KEY_x'].unique()

# getting new colour for every iteration
from itertools import cycle
cycol = cycle('bgrcmk') 

for i, p in enumerate(panels):
  test.loc[test['SOURCE_KEY_x'] == p, "sensor"] = i
  print(p,"\t",i)
# Out:
# 4UPUqMRk7TRMgml 	 0
# 81aHJ1q11NBPMrL 	 1
# 9kRcWv60rDACzjR 	 2
# Et9kgGMDl729KT4 	 3
# IQ2d7wF4YD8zU1Q 	 4
# LYwnQax7tkwH5Cb 	 5
# LlT2YUhhzqhg5Sw 	 6
# Mx2yZCDsyf6DPfv 	 7
# NgDl19wMapZy17u 	 8
# PeE6FRyGXUgsRhN 	 9
# Qf4GUc1pJu5T6c6 	 10
# Quc1TzYxW2pYoWX 	 11
# V94E5Ben1TlhnDV 	 12
# WcxssY2VbP4hApt 	 13
# mqwcsP2rE7J0TFp 	 14
# oZ35aAeoifZaQzV 	 15
# oZZkBaNadn6DNKz 	 16
# q49J1IKaHRwDQnt 	 17
# rrq4fwE8jgrTyWY 	 18
# vOuJvMaM2sgwLmb 	 19
# xMbIugepa2P7lBB 	 20
# xoJJ8DcxJEcupym 	 21

# %% [markdown]
# Creating a new column for the difference in temperatures

# %%
full_table2['TEMPERATURE_DIFFERENCE']=full_table2['MODULE_TEMPERATURE'] - full_table2['AMBIENT_TEMPERATURE']
print(full_table2)
# Out:
#                 DATE_TIME  PLANT_ID  ... IRRADIATION  TEMPERATURE_DIFFERENCE
# 0     2020-05-15 00:00:00   4136001  ...         0.0               -1.943975
# 1     2020-05-15 00:00:00   4136001  ...         0.0               -1.943975
# 2     2020-05-15 00:00:00   4136001  ...         0.0               -1.943975
# 3     2020-05-15 00:00:00   4136001  ...         0.0               -1.943975
# 4     2020-05-15 00:00:00   4136001  ...         0.0               -1.943975
# ...                   ...       ...  ...         ...                     ...
# 67693 2020-06-17 23:45:00   4136001  ...         0.0               -0.666963
# 67694 2020-06-17 23:45:00   4136001  ...         0.0               -0.666963
# 67695 2020-06-17 23:45:00   4136001  ...         0.0               -0.666963
# 67696 2020-06-17 23:45:00   4136001  ...         0.0               -0.666963
# 67697 2020-06-17 23:45:00   4136001  ...         0.0               -0.666963
#
# [67698 rows x 12 columns]

# %%
show(full_table2.head(10))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DATE_TIME</th>
#       <th>PLANT_ID</th>
#       <th>SOURCE_KEY_x</th>
#       <th>DC_POWER</th>
#       <th>AC_POWER</th>
#       <th>DAILY_YIELD</th>
#       <th>TOTAL_YIELD</th>
#       <th>SOURCE_KEY_y</th>
#       <th>AMBIENT_TEMPERATURE</th>
#       <th>MODULE_TEMPERATURE</th>
#       <th>IRRADIATION</th>
#       <th>TEMPERATURE_DIFFERENCE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>4UPUqMRk7TRMgml</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>9425.000000</td>
#       <td>2.429011e+06</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#       <td>-1.943975</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>81aHJ1q11NBPMrL</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>1.215279e+09</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#       <td>-1.943975</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>9kRcWv60rDACzjR</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3075.333333</td>
#       <td>2.247720e+09</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#       <td>-1.943975</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>Et9kgGMDl729KT4</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>269.933333</td>
#       <td>1.704250e+06</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#       <td>-1.943975</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>IQ2d7wF4YD8zU1Q</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>3177.000000</td>
#       <td>1.994153e+07</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#       <td>-1.943975</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>LYwnQax7tkwH5Cb</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1872.500000</td>
#       <td>1.794959e+09</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#       <td>-1.943975</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>LlT2YUhhzqhg5Sw</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1094.357143</td>
#       <td>2.825928e+08</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#       <td>-1.943975</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>Mx2yZCDsyf6DPfv</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>5692.200000</td>
#       <td>2.453646e+06</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#       <td>-1.943975</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>NgDl19wMapZy17u</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1866.200000</td>
#       <td>1.115126e+08</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#       <td>-1.943975</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2020-05-15</td>
#       <td>4136001</td>
#       <td>PeE6FRyGXUgsRhN</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>651.200000</td>
#       <td>1.348351e+09</td>
#       <td>iq8k7ZNt4Mwm3w0</td>
#       <td>27.004764</td>
#       <td>25.060789</td>
#       <td>0.0</td>
#       <td>-1.943975</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Trying various plots for finding relations

# %%
# plt.figure(figsize=(28,20))
# for i in panels[:]:
#   myvariable = test[test['SOURCE_KEY_x']==i]
#   for ind,j in enumerate(['DATE_TIME', 'IRRADIATION', 'MODULE_TEMPERATURE', 'AMBIENT_TEMPERATURE']):
#     plt.subplot(5,1,ind+1)
#     plt.scatter(myvariable[j], myvariable['TOTAL_YIELD'], alpha=1, s=0.3, c = next(cycol))
#     plt.xlabel(j)
#     plt.ylabel('TOTAL_YIELD')
# plt.show()

# %%
# plt.figure(figsize=(28,20))
# for i in panels[:]:
#   myvariable = test[test['SOURCE_KEY_x']==i]
#   for ind,j in enumerate(['DATE_TIME', 'TOTAL_YIELD', 'MODULE_TEMPERATURE', 'AMBIENT_TEMPERATURE']):
#     plt.subplot(5,1,ind+1)
#     plt.scatter(myvariable[j], myvariable['IRRADIATION'], alpha=1, s=0.3, c = next(cycol))
#     plt.xlabel(j)
#     plt.ylabel('IRRADIATION')
# plt.show()

# %%
plt.figure(figsize=(28,20))
for i in panels[:]:
  myvariable = test[test['SOURCE_KEY_x']==i]
  for ind,j in enumerate(['DATE_TIME', 'IRRADIATION', 'MODULE_TEMPERATURE', 'AMBIENT_TEMPERATURE']):
    plt.subplot(5,1,ind+1)
    plt.scatter(myvariable[j], myvariable['DC_POWER'], alpha=1, s=0.3, c = next(cycol))
    plt.xlabel(j)
    plt.ylabel('DC_POWER')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """

# %%
import plotly.express as px
for i in panels[:]:
  myvariable = test[test['SOURCE_KEY_x']==i]
  fig = px.scatter(full_table2, x = 'IRRADIATION', y = 'TEMPERATURE_DIFFERENCE', trendline="ols")
fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import seaborn as sns
graph= sns.lmplot(x='AMBIENT_TEMPERATURE', y='DC_POWER', hue='sensor',
               data=test, scatter_kws={"s": 1}, height = 5, aspect = 1.6, palette="Set2")

# %%
graph= sns.lmplot(x='MODULE_TEMPERATURE', y='DC_POWER', hue='sensor',
               data=test, scatter_kws={"s": 1}, height = 5, aspect = 1.6, palette="Set2")

# %%
graph= sns.lmplot(x='IRRADIATION', y='DC_POWER', hue='sensor',
               data=test, scatter_kws={"s": 1}, height = 5, aspect = 1.6, palette="Set2")

# %%
graph= sns.lmplot(x='IRRADIATION', y='DC_POWER', col='sensor', col_wrap=3, 
               data=test, scatter_kws={"s": 1, "color": next(cycol)}, height = 3, aspect = 2, line_kws={"color": next(cycol)})

# %% [markdown]
# ##Cleaning/Maintenance

# %% [markdown]
# Deleting all rows where DC is 0

# %%
newtest = test[:]
print(newtest.shape, test.shape)
# Out:
# (67698, 12) (67698, 12)

# %%
newtest = newtest[newtest.DC_POWER != 0]
print(newtest.shape, test.shape)
# Out:
# (32036, 12) (67698, 12)

# %% [markdown]
# Visualising charts again

# %%
import seaborn as sns
graph= sns.lmplot(x='AMBIENT_TEMPERATURE', y='DC_POWER', hue='sensor',
               data=newtest, scatter_kws={"s": 1}, height = 5, aspect = 1.6, palette="Set2")

# %%
graph= sns.lmplot(x='MODULE_TEMPERATURE', y='DC_POWER', hue='sensor',
               data=newtest, scatter_kws={"s": 1}, height = 5, aspect = 1.6, palette="Set2")

# %%
graph= sns.lmplot(x='IRRADIATION', y='DC_POWER', hue='sensor',
               data=newtest, scatter_kws={"s": 1}, height = 5, aspect = 1.6, palette="Set2")

# %%
graph= sns.lmplot(x='IRRADIATION', y='DC_POWER', col='sensor', col_wrap=3, 
               data=newtest, scatter_kws={"s": 1, "color": next(cycol)}, height = 3, aspect = 2, line_kws={"color": next(cycol)})

# %% [markdown]
# Finding the slope for each sensor

# %%
from sklearn import linear_model
from sklearn import metrics
MAE=[]
MSE=[]
RMSE=[]

regr = linear_model.LinearRegression()
slopes = []
for i in range(len(panels[:])):
  myvariable = test[test['sensor']==i]
  x = myvariable['IRRADIATION'].values.reshape(-1,1)
  y = myvariable['DC_POWER'].values.reshape(-1,1)
  regr.fit(x,y)
  slopes.append(round(float(regr.coef_[0]),3))
  print(i,slopes[-1])

  MAE.append((round(float(metrics.mean_absolute_error(myvariable['IRRADIATION'], myvariable['DC_POWER'])),3)))
  MSE.append((round(float(metrics.mean_squared_error(myvariable['IRRADIATION'], myvariable['DC_POWER'])),3)))
  RMSE.append((round(float(np.sqrt(metrics.mean_squared_error(myvariable['IRRADIATION'], myvariable['DC_POWER']))),3)))
# Out:
# 0 1092.603
# 1 836.599
# 2 900.286
# 3 618.826
# 4 1296.756
# 5 610.872
# 6 913.194
# 7 1143.8
# 8 1221.299
# 9 939.598
# 10 1110.596
# 11 571.993
# 12 1012.071
# 13 921.608
# 14 1229.127
# 15 1094.123
# 16 952.452
# 17 790.672
# 18 697.95
# 19 992.182
# 20 1277.023
# 21 867.255

# %% [markdown]
# Printing the values of errors

# %%
for i in range(len(panels[:])):
  print(f"For the sensor number {i}    MAE={MAE[i]}    MSE={MSE[i]}    RMSE={RMSE[i]}")
# Out:
# For the sensor number 0    MAE=277.591    MSE=238025.369    RMSE=487.878
# For the sensor number 1    MAE=230.681    MSE=182841.999    RMSE=427.6
# For the sensor number 2    MAE=244.521    MSE=196272.841    RMSE=443.027
# For the sensor number 3    MAE=188.15    MSE=129018.779    RMSE=359.192
# For the sensor number 4    MAE=285.327    MSE=239089.277    RMSE=488.968
# For the sensor number 5    MAE=196.213    MSE=138305.62    RMSE=371.895
# For the sensor number 6    MAE=245.356    MSE=196304.943    RMSE=443.063
# For the sensor number 7    MAE=284.833    MSE=245951.734    RMSE=495.935
# For the sensor number 8    MAE=273.333    MSE=222464.226    RMSE=471.661
# For the sensor number 9    MAE=248.543    MSE=199269.634    RMSE=446.396
# For the sensor number 10    MAE=278.574    MSE=239581.035    RMSE=489.47
# For the sensor number 11    MAE=173.164    MSE=105604.951    RMSE=324.969
# For the sensor number 12    MAE=262.006    MSE=219700.785    RMSE=468.723
# For the sensor number 13    MAE=245.137    MSE=201118.246    RMSE=448.462
# For the sensor number 14    MAE=275.509    MSE=223800.435    RMSE=473.076
# For the sensor number 15    MAE=276.875    MSE=237832.853    RMSE=487.681
# For the sensor number 16    MAE=255.777    MSE=209990.127    RMSE=458.247
# For the sensor number 17    MAE=226.048    MSE=172498.472    RMSE=415.329
# For the sensor number 18    MAE=209.06    MSE=152109.813    RMSE=390.013
# For the sensor number 19    MAE=261.946    MSE=217669.711    RMSE=466.551
# For the sensor number 20    MAE=280.514    MSE=231003.035    RMSE=480.628
# For the sensor number 21    MAE=240.796    MSE=189906.119    RMSE=435.782

# %%
MAEcopy=MAE.copy()
for i in range(len(panels[:])):
  print(f"Mean Absolute Error for sensor {MAE.index(max(MAEcopy))} is {max(MAEcopy)}")
  MAEcopy.remove(max(MAEcopy))
# Out:
# Mean Absolute Error for sensor 4 is 285.327
# Mean Absolute Error for sensor 7 is 284.833
# Mean Absolute Error for sensor 20 is 280.514
# Mean Absolute Error for sensor 10 is 278.574
# Mean Absolute Error for sensor 0 is 277.591
# Mean Absolute Error for sensor 15 is 276.875
# Mean Absolute Error for sensor 14 is 275.509
# Mean Absolute Error for sensor 8 is 273.333
# Mean Absolute Error for sensor 12 is 262.006
# Mean Absolute Error for sensor 19 is 261.946
# Mean Absolute Error for sensor 16 is 255.777
# Mean Absolute Error for sensor 9 is 248.543
# Mean Absolute Error for sensor 6 is 245.356
# Mean Absolute Error for sensor 13 is 245.137
# Mean Absolute Error for sensor 2 is 244.521
# Mean Absolute Error for sensor 21 is 240.796
# Mean Absolute Error for sensor 1 is 230.681
# Mean Absolute Error for sensor 17 is 226.048
# Mean Absolute Error for sensor 18 is 209.06
# Mean Absolute Error for sensor 5 is 196.213
# Mean Absolute Error for sensor 3 is 188.15
# Mean Absolute Error for sensor 11 is 173.164

# %%
RMSEcopy=RMSE.copy()
for i in range(len(panels[:])):
  print(f"Root Mean Square Error for sensor {RMSE.index(max(RMSEcopy))} is {max(RMSEcopy)}")
  RMSEcopy.remove(max(RMSEcopy))
# Out:
# Root Mean Square Error for sensor 7 is 495.935
# Root Mean Square Error for sensor 10 is 489.47
# Root Mean Square Error for sensor 4 is 488.968
# Root Mean Square Error for sensor 0 is 487.878
# Root Mean Square Error for sensor 15 is 487.681
# Root Mean Square Error for sensor 20 is 480.628
# Root Mean Square Error for sensor 14 is 473.076
# Root Mean Square Error for sensor 8 is 471.661
# Root Mean Square Error for sensor 12 is 468.723
# Root Mean Square Error for sensor 19 is 466.551
# Root Mean Square Error for sensor 16 is 458.247
# Root Mean Square Error for sensor 13 is 448.462
# Root Mean Square Error for sensor 9 is 446.396
# Root Mean Square Error for sensor 6 is 443.063
# Root Mean Square Error for sensor 2 is 443.027
# Root Mean Square Error for sensor 21 is 435.782
# Root Mean Square Error for sensor 1 is 427.6
# Root Mean Square Error for sensor 17 is 415.329
# Root Mean Square Error for sensor 18 is 390.013
# Root Mean Square Error for sensor 5 is 371.895
# Root Mean Square Error for sensor 3 is 359.192
# Root Mean Square Error for sensor 11 is 324.969

# %% [markdown]
# Finding the deviation of a slope relative to the average slope

# %%
slope_difference=[]
for i in slopes[:]:
  slope_difference.append(abs(i-np.mean(slopes)))

arranged_diff={}
for i in slope_difference:
  arranged_diff[slope_difference.index(i)]=i

arranged_diff=sorted(arranged_diff.items(), key=lambda x: x[1], reverse=True)
for key, value in arranged_diff:
    print(f"The slope difference for sensor {key} is {round(value,3)}")
# Out:
# The slope difference for sensor 11 is 386.684
# The slope difference for sensor 5 is 347.805
# The slope difference for sensor 3 is 339.851
# The slope difference for sensor 4 is 338.079
# The slope difference for sensor 20 is 318.346
# The slope difference for sensor 14 is 270.45
# The slope difference for sensor 8 is 262.622
# The slope difference for sensor 18 is 260.727
# The slope difference for sensor 7 is 185.123
# The slope difference for sensor 17 is 168.005
# The slope difference for sensor 10 is 151.919
# The slope difference for sensor 15 is 135.446
# The slope difference for sensor 0 is 133.926
# The slope difference for sensor 1 is 122.078
# The slope difference for sensor 21 is 91.422
# The slope difference for sensor 2 is 58.391
# The slope difference for sensor 12 is 53.394
# The slope difference for sensor 6 is 45.483
# The slope difference for sensor 13 is 37.069
# The slope difference for sensor 19 is 33.505
# The slope difference for sensor 9 is 19.079
# The slope difference for sensor 16 is 6.225

# %% [markdown]
# ##Forecast/Prediction

# %% [markdown]
# Neural Networks Keras

# %%
dataset = full_table2.values
dataset
# Out:
# array([[Timestamp('2020-05-15 00:00:00'), 4136001, '4UPUqMRk7TRMgml',
#         ..., 25.0607889, 0.0, -1.9439748000000066],
#        [Timestamp('2020-05-15 00:00:00'), 4136001, '81aHJ1q11NBPMrL',
#         ..., 25.0607889, 0.0, -1.9439748000000066],
#        [Timestamp('2020-05-15 00:00:00'), 4136001, '9kRcWv60rDACzjR',
#         ..., 25.0607889, 0.0, -1.9439748000000066],
#        ...,
#        [Timestamp('2020-06-17 23:45:00'), 4136001, 'vOuJvMaM2sgwLmb',
#         ..., 22.53590765517241, 0.0, -0.666963034482766],
#        [Timestamp('2020-06-17 23:45:00'), 4136001, 'xMbIugepa2P7lBB',
#         ..., 22.53590765517241, 0.0, -0.666963034482766],
#        [Timestamp('2020-06-17 23:45:00'), 4136001, 'xoJJ8DcxJEcupym',
#         ..., 22.53590765517241, 0.0, -0.666963034482766]], dtype=object)

# %%
X = dataset[:,3:7]
Y = dataset[:,10]
from sklearn.model_selection import train_test_split
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X, Y, test_size=0.3)
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %% [markdown]
# Training the model

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential([
    Dense(32, activation='relu', input_shape=(4,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

model.add(Dense(1, input_dim=1, kernel_initializer ='normal', activation='relu'))

model.compile(optimizer='adam',loss='mean_squared_error')

X_train=np.asarray(X_train).astype(np.int)
Y_train=np.asarray(Y_train).astype(np.int)

X_val=np.asarray(X_val).astype(np.int)
Y_val=np.asarray(Y_val).astype(np.int)

from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

hist = model.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 1481/1481 [==============================] - 3s 2ms/step - loss: 0.0048 - val_loss: 0.0026
# Epoch 2/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 3/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 4/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 5/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 6/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 7/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 8/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0040 - val_loss: 0.0026
# Epoch 9/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 10/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 11/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 12/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 13/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 14/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 15/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 16/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 17/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0040 - val_loss: 0.0026
# Epoch 18/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 19/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 20/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 21/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 22/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 23/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 24/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 25/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 26/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 27/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 28/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 29/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 30/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 31/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 32/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 33/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 34/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 35/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 36/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 37/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 38/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 39/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 40/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 41/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 42/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 43/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 44/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 45/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 46/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 47/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 48/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 49/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 50/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 51/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 52/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 53/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 54/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 55/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 56/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 57/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 58/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 59/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 60/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 61/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 62/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 63/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 64/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 65/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 66/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 67/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 68/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 69/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 70/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 71/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 72/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 73/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 74/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 75/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 76/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0041 - val_loss: 0.0026
# Epoch 77/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 78/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 79/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 80/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 81/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 82/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 83/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0040 - val_loss: 0.0026
# Epoch 84/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0038 - val_loss: 0.0026
# Epoch 85/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 86/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 87/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 88/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 89/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 90/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 91/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 92/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 93/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 94/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 95/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 96/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 97/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 98/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0041 - val_loss: 0.0026
# Epoch 99/100
# 1481/1481 [==============================] - 2s 1ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 100/100
# 1481/1481 [==============================] - 2s 2ms/step - loss: 0.0033 - val_loss: 0.0026

# %% [markdown]
# Evaluating the loss

# %%
X_test=np.asarray(X_test).astype(np.int)
Y_test=np.asarray(Y_test).astype(np.int)

model.evaluate(X_test, Y_test)
# Out:
# 318/318 [==============================] - 0s 969us/step - loss: 0.0032
# 0.0032496307976543903

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.ylim(0.00, 0.01)
plt.show()

# %% [markdown]
# Prophet

# %%
def predict(data, with_regr = True, num_days = 0, interval_width=0.05):
  myvariable = data.copy()
  myvariable.rename(columns={'DATE_TIME':'ds','TOTAL_YIELD':'y'}, inplace=True)
  from fbprophet import Prophet
  m = Prophet(interval_width=interval_width, daily_seasonality=True,
              weekly_seasonality=False)
  if with_regr:
    m.add_regressor('IRRADIATION')
  model = m.fit(myvariable)
  if with_regr:
    future = weather2[['DATE_TIME',"IRRADIATION"]]
    future.columns = ['ds','IRRADIATION']
  else:
    future = m.make_future_dataframe(periods=24*num_days,freq='h')
    future.tail()
  forecast = m.predict(future)
  forecast.tail()
  plot1 = m.plot(forecast)
  # plot2 = m.plot_components(forecast)

predict(test[test.sensor==0])
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
newtest = newtest[newtest.TOTAL_YIELD >2300000]
print(newtest.shape, test.shape)
# Out:
# (28524, 12) (67698, 12)

# %%
predict(newtest[newtest.sensor==0])
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
predict(test[test.sensor==0], with_regr=False, num_days = 15)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
predict(newtest[newtest.sensor==0], with_regr=False, num_days = 15)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %% [markdown]
# ##Repair

# %%
plt.rcParams['figure.figsize'] = (14, 8)
myvariable = test[test['sensor']==0]
myvariable = myvariable[myvariable['DAILY_YIELD']>=0]
plt.scatter(myvariable.DATE_TIME, myvariable.DAILY_YIELD, s=1, c=next(cycol))
plt.ylabel('Daily Yield')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
plt.figure(figsize=(28,20))
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
for i in range(len(panels[:])):
  myvariable = test[test['sensor']==i]
  myvariable = myvariable[myvariable['TOTAL_YIELD']>=(myvariable['TOTAL_YIELD'].iloc[0])]
  plt.subplot(5,5, i+1)
  plt.scatter(myvariable.DATE_TIME, myvariable.TOTAL_YIELD,  s=1, c=next(cycol))
  plt.ylabel(f'Daily Yield for sensor {i}')
  plt.xlabel('Date')
  plt.xticks(rotation = 45)
plt.show()
